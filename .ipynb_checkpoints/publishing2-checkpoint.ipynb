# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import scipy.stats as st

# %%
pd = pd.read_csv("extract.csv")
pd
# Out:
#                 Timestamp             genre payment                 rights  \
# 0       6/11/2020 7:09:01          Academic  $1,000              Worldwide
# 1        6/7/2020 0:17:09          Academic  $3,000              Worldwide
# 2        6/9/2020 7:15:32          Academic      $0     North America Only
# 3       6/10/2020 9:23:46          Academic    $500              Worldwide
# 4       6/10/2020 9:24:52          Academic      $0              Worldwide
# ...                   ...               ...     ...                    ...
# 2802    11/4/2020 9:57:10            Poetry  762.39              Worldwide
# 2803  11/11/2020 13:24:01  Literary Fiction    1.35     North America Only
# 2804  11/30/2020 18:44:52  Literary Fiction   25000              Worldwide
# 2805   12/11/2020 6:39:16                PB   10000     North America Only
# 2806  12/11/2020 10:12:13  Literary Fiction    1000  English Language Only
#
#       year                            publisher debut agent  \
# 0     2018                             Springer   Yes    No
# 1     2019                     University Press    No   Yes
# 2     2011           Louisiana State University   Yes    No
# 3     2013                              Praeger    No    No
# 4     2012                     University Press   Yes    No
# ...    ...                                  ...   ...   ...
# 2802  2019  Penguin Random House (and Imprints)    No    No
# 2803  2013                          Small/Indie   Yes    No
# 2804  2011                          Small/Indie   Yes   Yes
# 2805  2020                          Small/Indie    No    No
# 2806  2014                          Small/Indie   Yes   Yes
#
#                                              race     gender orientation  \
# 0                                           White    Cis Man    Straight
# 1                                           White        NaN    Straight
# 2                                           White  Cis Woman    Straight
# 3                                     Multiracial  Cis Woman    Straight
# 4                                     Multiracial  Cis Woman    Straight
# ...                                           ...        ...         ...
# 2802  Arab/West Asian/Middle Eastern, South Asian  Cis Woman    Straight
# 2803                                        White    Cis Man    Straight
# 2804                                        White  Cis Woman    Straight
# 2805                               Latin American  Cis Woman    Straight
# 2806                                        White    Cis Man         Gay
#
#      disability                             author  \
# 0            No  Moorkens Castilho Gaspari Doherty
# 1            No                                NaN
# 2            No                                NaN
# 3            No                                NaN
# 4            No                                NaN
# ...         ...                                ...
# 2802        Yes                                NaN
# 2803         No                                NaN
# 2804         No                                NaN
# 2805         No                                NaN
# 2806         No                                NaN
#
#                                title comptitle additionalcomments
# 0     Translation Quality Assessment       NaN                NaN
# 1                                NaN       NaN                NaN
# 2                                NaN       NaN                NaN
# 3                                NaN       NaN                NaN
# 4                                NaN       NaN                NaN
# ...                              ...       ...                ...
# 2802                             NaN        No                NaN
# 2803                             NaN       NaN                NaN
# 2804                             NaN       NaN                NaN
# 2805                             NaN       NaN                NaN
# 2806                             NaN        No                NaN
#
# [2807 rows x 16 columns]

# %%
pd_task2a = pd[["payment", "race"]]
pd_task2a = pd_task2a.dropna()
pd_task2a
# Out:
#      payment                                         race
# 0     $1,000                                        White
# 1     $3,000                                        White
# 2         $0                                        White
# 3       $500                                  Multiracial
# 4         $0                                  Multiracial
# ...      ...                                          ...
# 2802  762.39  Arab/West Asian/Middle Eastern, South Asian
# 2803    1.35                                        White
# 2804   25000                                        White
# 2805   10000                               Latin American
# 2806    1000                                        White
#
# [2531 rows x 2 columns]

# %%
pd_task2a = pd_task2a[(pd_task2a["race"] == "Black") | (pd_task2a["race"] == "White")]
pd_task2a[["payment"]] = pd_task2a[["payment"]].replace("[\$,]", "", regex = True).astype(float)
pd_task2a = pd_task2a[(pd_task2a["payment"] > 10) & (pd_task2a["payment"] <= 1000000)]
pd_task2a
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_16948\2973331663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_task2a[["payment"]] = pd_task2a[["payment"]].replace("[\$,]", "", regex = True).astype(float)
#        payment   race
# 0       1000.0  White
# 1       3000.0  White
# 5       1000.0  Black
# 6     285000.0  White
# 11     50000.0  White
# ...        ...    ...
# 2798   55000.0  White
# 2800   25000.0  Black
# 2801  100000.0  Black
# 2804   25000.0  White
# 2806    1000.0  White
#
# [1923 rows x 2 columns]

# %%
pd_task2a_white = pd_task2a["race"] == "White"
pd_task2a_black = pd_task2a["race"] == "Black"

# %%
pd_task2a_whitemean = pd_task2a.loc[pd_task2a_white, "payment"].mean()
pd_task2a_blackmean = pd_task2a.loc[pd_task2a_black, "payment"].mean()
print("The mean payment for white authors was: " + str(pd_task2a_whitemean))
print("The mean payment for black authors was: " + str(pd_task2a_blackmean))
# Out:
# The mean payment for white authors was: 44573.32590529248
# The mean payment for black authors was: 102451.1875

# %%
pd_task2a_2 = pd_task2a
pd_task2a_2["race"] = pd_task2a[["race"]].replace("Black", 1, regex = True)
pd_task2a_2["race"] = pd_task2a_2[["race"]].replace("White", 0, regex = True)
pd_task2a_2
# Out:
#        payment  race
# 0       1000.0     0
# 1       3000.0     0
# 5       1000.0     1
# 6     285000.0     0
# 11     50000.0     0
# ...        ...   ...
# 2798   55000.0     0
# 2800   25000.0     1
# 2801  100000.0     1
# 2804   25000.0     0
# 2806    1000.0     0
#
# [1923 rows x 2 columns]

# %%
pd_task2a_model = st.linregress(pd_task2a_2["payment"], pd_task2a_2["race"])
pd_task2a_model
# Out:
# LinregressResult(slope=3.903777977876248e-07, intercept=0.04765829345032821, rvalue=0.15031377897584397, pvalue=3.4736540046778234e-11, stderr=5.85814453728974e-08, intercept_stderr=0.006297664479145674)

# %%
chart_race = ["White", "Black"]
chart_mean = [pd_task2a_whitemean, pd_task2a_blackmean]

plt.bar(chart_race, chart_mean)
plt.xlabel("What race was the author?")
plt.ylabel("Payment")
plt.show()

# %%
pd_task2b = pd[["payment", "race", "agent"]]
pd_task2b = pd_task2b[pd_task2b["race"] == "Black"]
pd_task2b = pd_task2b.dropna()
pd_task2b[["payment"]] = pd_task2b[["payment"]].replace("[\$,]", "", regex = True).astype(float)
pd_task2b = pd_task2b[(pd_task2b["payment"] > 10) & (pd_task2b["payment"] <= 1000000)]
pd_task2b
# Out:
#         payment   race agent
# 5        1000.0  Black    No
# 21      50000.0  Black   Yes
# 57      50000.0  Black    No
# 191   1000000.0  Black   Yes
# 224   1000000.0  Black   Yes
# ...         ...    ...   ...
# 2785   400000.0  Black   Yes
# 2786   250000.0  Black   Yes
# 2797    15000.0  Black   Yes
# 2800    25000.0  Black   Yes
# 2801   100000.0  Black   Yes
#
# [100 rows x 3 columns]

# %%
task2b_agent = pd_task2b["agent"] == "Yes"
task2b_noagent = pd_task2b["agent"] == "No"

agent_mean = pd_task2b.loc[task2b_agent, "payment"].mean()
noagent_mean = pd_task2b.loc[task2b_noagent, "payment"].mean()
print("The mean payment for black authors with agents was: " + str(agent_mean))
print("The mean payment for black authors without agents was: " + str(noagent_mean))
# Out:
# The mean payment for black authors with agents was: 128118.5617977528
# The mean payment for black authors without agents was: 17563.636363636364

# %%
chart_race = ["Agent", "No Agent"]
chart_mean = [agent_mean, noagent_mean]

plt.bar(chart_race, chart_mean)
plt.xlabel("Did the black author have an agent?")
plt.ylabel("Payment")
plt.show()

# %%
pd_task2b_final = pd_task2b[["payment", "agent"]]
pd_task2b_final
# Out:
#         payment agent
# 5        1000.0    No
# 21      50000.0   Yes
# 57      50000.0    No
# 191   1000000.0   Yes
# 224   1000000.0   Yes
# ...         ...   ...
# 2785   400000.0   Yes
# 2786   250000.0   Yes
# 2797    15000.0   Yes
# 2800    25000.0   Yes
# 2801   100000.0   Yes
#
# [100 rows x 2 columns]

# %%
pd_task2b_final["agent"] = pd_task2b_final[["agent"]].replace("Yes", 1, regex = True)
pd_task2b_final["agent"] = pd_task2b_final[["agent"]].replace("No", 0, regex = True)
pd_task2b_final
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_16948\2795717907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_task2b_final["agent"] = pd_task2b_final[["agent"]].replace("Yes", 1, regex = True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_16948\2795717907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_task2b_final["agent"] = pd_task2b_final[["agent"]].replace("No", 0, regex = True)
#         payment  agent
# 5        1000.0      0
# 21      50000.0      1
# 57      50000.0      0
# 191   1000000.0      1
# 224   1000000.0      1
# ...         ...    ...
# 2785   400000.0      1
# 2786   250000.0      1
# 2797    15000.0      1
# 2800    25000.0      1
# 2801   100000.0      1
#
# [100 rows x 2 columns]

# %%
pd_task2b_model = st.linregress(pd_task2b_final["payment"], pd_task2b_final["agent"])
pd_task2b_model
# Out:
# LinregressResult(slope=1.787101864639684e-07, intercept=0.8692772099789007, rvalue=0.14056063225114304, pvalue=0.16305506968110003, stderr=1.2715673804504538e-07, intercept_stderr=0.034592643699203)
