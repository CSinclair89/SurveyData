# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
pd = pd.read_csv("extract.csv", header = None)
pd
# Out:
#                        0                 1        2                      3   \
# 0               Timestamp             genre  payment                 rights
# 1       6/11/2020 7:09:01          Academic   $1,000              Worldwide
# 2        6/7/2020 0:17:09          Academic   $3,000              Worldwide
# 3        6/9/2020 7:15:32          Academic       $0     North America Only
# 4       6/10/2020 9:23:46          Academic     $500              Worldwide
# ...                   ...               ...      ...                    ...
# 2803    11/4/2020 9:57:10            Poetry   762.39              Worldwide
# 2804  11/11/2020 13:24:01  Literary Fiction     1.35     North America Only
# 2805  11/30/2020 18:44:52  Literary Fiction    25000              Worldwide
# 2806   12/11/2020 6:39:16                PB    10000     North America Only
# 2807  12/11/2020 10:12:13  Literary Fiction     1000  English Language Only
#
#         4                                    5      6      7   \
# 0     year                            publisher  debut  agent
# 1     2018                             Springer    Yes     No
# 2     2019                     University Press     No    Yes
# 3     2011           Louisiana State University    Yes     No
# 4     2013                              Praeger     No     No
# ...    ...                                  ...    ...    ...
# 2803  2019  Penguin Random House (and Imprints)     No     No
# 2804  2013                          Small/Indie    Yes     No
# 2805  2011                          Small/Indie    Yes    Yes
# 2806  2020                          Small/Indie     No     No
# 2807  2014                          Small/Indie    Yes    Yes
#
#                                                8          9            10  \
# 0                                            race     gender  orientation
# 1                                           White    Cis Man     Straight
# 2                                           White        NaN     Straight
# 3                                           White  Cis Woman     Straight
# 4                                     Multiracial  Cis Woman     Straight
# ...                                           ...        ...          ...
# 2803  Arab/West Asian/Middle Eastern, South Asian  Cis Woman     Straight
# 2804                                        White    Cis Man     Straight
# 2805                                        White  Cis Woman     Straight
# 2806                               Latin American  Cis Woman     Straight
# 2807                                        White    Cis Man          Gay
#
#               11                                 12  \
# 0     disability                             author
# 1             No  Moorkens Castilho Gaspari Doherty
# 2             No                                NaN
# 3             No                                NaN
# 4             No                                NaN
# ...          ...                                ...
# 2803         Yes                                NaN
# 2804          No                                NaN
# 2805          No                                NaN
# 2806          No                                NaN
# 2807          No                                NaN
#
#                                   13         14                  15
# 0                              title  comptitle  additionalcomments
# 1     Translation Quality Assessment        NaN                 NaN
# 2                                NaN        NaN                 NaN
# 3                                NaN        NaN                 NaN
# 4                                NaN        NaN                 NaN
# ...                              ...        ...                 ...
# 2803                             NaN         No                 NaN
# 2804                             NaN        NaN                 NaN
# 2805                             NaN        NaN                 NaN
# 2806                             NaN        NaN                 NaN
# 2807                             NaN         No                 NaN
#
# [2808 rows x 16 columns]

# %%
pd_task1 = pd[["payment", "year"]]
pd_task1 = pd_task1.dropna()
pd_task1[["payment"]] = pd_task1[["payment"]].replace("[\$,]", "", regex = True).astype(float)
pd_task1 = pd_task1[(pd_task1["payment"] > 0) & (pd_task1["payment"] <= 1000000)]
pd_task1[["year"]] = pd_task1[["year"]].replace("2017, 2019", "2017", regex = True)
pd_task1[["year"]] = pd_task1[["year"]].replace("2020 release", "2020", regex = True)
pd_task1[["year"]] = pd_task1[["year"]].astype(int)
pd_task1 = pd_task1.sort_values(by = ["year"], ascending = True)
pd_task1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15060\4051829812.py in <module>
# ----> 1 pd_task1 = pd[["payment", "year"]]
#       2 pd_task1 = pd_task1.dropna()
#       3 pd_task1[["payment"]] = pd_task1[["payment"]].replace("[\$,]", "", regex = True).astype(float)
#       4 pd_task1 = pd_task1[(pd_task1["payment"] > 0) & (pd_task1["payment"] <= 1000000)]
#       5 pd_task1[["year"]] = pd_task1[["year"]].replace("2017, 2019", "2017", regex = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['payment', 'year'], dtype='object')] are in the [columns]"

# %%
pd_task1_x = pd_task1["payment"]
pd_task1_y = pd_task1["year"]

# %%
plt.scatter(pd_task1_x, pd_task1_y)
plt.xlabel("Year")
plt.ylabel("Payment (in millions)")
plt.show()

# %%
pd_task1_model = st.linregress(pd_task1_x, pd_task1_y)
pd_task1_model
